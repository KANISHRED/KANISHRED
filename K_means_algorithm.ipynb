# %% [markdown]
# <a href="https://colab.research.google.com/github/KANISHRED/KANISHRED/blob/main/K_means_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K Means Algorithm

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)

# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16,9)

# %matplotlib inline
data = pd.read_csv("Dataset-Kmeans-xclara.csv", error_bad_lines = False)
# Out:
# /Users/thejasveedevaraj/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Importing the dataset
data = pd.read_csv('Dataset-Kmeans-xclara.csv', error_bad_lines=False)
print(data.shape)
data.head()
# Out:
# (3000, 2)
# /Users/thejasveedevaraj/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
data.describe()
# Out:
#                 V1           V2
# count  3000.000000  3000.000000
# mean     40.611358    22.862141
# std      25.859054    31.759714
# min     -22.495990   -38.795500
# 25%      18.462790    -4.003494
# 50%      41.552210    13.827390
# 75%      62.249480    55.729100
# max     104.376600    87.313700

# %%
# Getting the values and plotting it
f1 = data['V1'].values
f2 = data['V2'].values

plt.scatter(f1, f2, c='blue', s=7)

# %%
f1
# Out:
# array([ 2.072345, 17.93671 ,  1.083576, ..., 64.46532 , 90.72282 ,
#        64.87976 ])

# %%
f2
# Out:
# array([ -3.241693,  15.78481 ,   7.319176, ..., -10.50136 , -12.25584 ,
#        -24.87731 ])

# %%
X = np.array(list(zip(f1, f2)))

# %%
X
# Out:
# array([[  2.072345,  -3.241693],
#        [ 17.93671 ,  15.78481 ],
#        [  1.083576,   7.319176],
#        ...,
#        [ 64.46532 , -10.50136 ],
#        [ 90.72282 , -12.25584 ],
#        [ 64.87976 , -24.87731 ]])

# %%
X.shape
# Out:
# (3000, 2)

# %% [markdown]
# # K-Means using Scikit Learn

# %%
from sklearn.cluster import KMeans

# Number of clusters
kmeans = KMeans(n_clusters=3)

# Fitting the input data
kmeans = kmeans.fit(X)

# %%
# Getting the cluster labels
labels = kmeans.predict(X)

# %%
labels
# Out:
# array([1, 1, 1, ..., 2, 2, 2], dtype=int32)

# %%
# Centroid values
centroids = kmeans.cluster_centers_

# %%
print(centroids) # From sci-kit learn
# Out:
# [[  9.4780459   10.686052  ]
#  [ 40.68362784  59.71589274]
#  [ 69.92418447 -10.11964119]]

# %%
labels
# Out:
# array([1, 1, 1, ..., 2, 2, 2], dtype=int32)

# %%
plt.scatter(f1, f2, c = labels, s=7)
